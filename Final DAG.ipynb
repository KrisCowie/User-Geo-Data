# %% [markdown]
# ### 4b. Pipeline Dependency We use a modular design on all of our data analysis tasks. To get to a final product, we organize steps using a data pipeline. One task may require the output of one or multiple other tasks to run successfully. This creates dependencies between tasks.
#
# We also require the pipeline to be flexible. This means a new task may enter a running pipeline anytime that may not satisfy the tasks' dependencies. In this event, we may have a set of tasks already running or completed in the pipeline, and we will need to map out which tasks are prerequisites for the newest task so the pipeline can execute them in the correct order. For optimal pipeline execution, when we map out the necessary tasks required to execute the new task, we want to avoid scheduling tasks that have already been executed.
#
# If we treat each task as a node and the dependencies between a pair of tasks as directed edges, we can construct a DAG (Wiki: Directed Acyclic Graph).
#
# Consider the following scenario. At a certain stage of our data processing, we have a set of tasks (starting tasks) that we know all its prerequisite tasks have been executed, and we wish to reach a later goal task. We need to map out a path that indicates the order of executions on tasks that finally leads to the goal task. We are looking for a solution that satisfies both necessity and sufficiency -- if a task is not a prerequisite task of goal, or its task is a prerequisite task for starting tasks (already been executed), then it shouldn't be included in the path. The path needs to follow a correct topological ordering of the DAG, hence a task needs to be placed behind all its necessary prerequisite tasks in the path.
#
# Note: A starting task should be included in the path, if and only if it's a prerequisite of the goal task
#
# For example, we have 6 tasks [A, B, C, D, E, F], C depends on A (denoted as A->C), B->C, C->E, E->F. A new job has at least 2 tasks and at most 6 tasks, each task can only appear once.
#
# Examples:
#
# Inputs: starting task: A, goal task: F, output: A,B,C,E,F or B,A,C,E,F. Input: starting task: A,C, goal task:'F', outputs: C,E,F. You will find the starting task and the goal task in question.txt file, a list of all tasks in task_ids.txt, and dependencies in relations.txt.

# %% [markdown]
# ### Answer
# I tried a wide range of different processes to accomplish this, and eventually alighted up using depth first search traversal.
# Basically we want to look from the end input backwards, to identify the connections to each node (the dependencies) as we move from the goal to the beginning task / node.
#
# ![image.png](attachment:528702a6-c93b-4ea8-8216-3a1011db8d9e.png)![image.png](attachment:9048ece2-7582-4930-931f-8435a92ece0f.png)

# %%
# Python program to for tree traversals
  
# A class that represents an individual node in a
# Binary Tree
class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key
  
  
# A function to do inorder tree traversal
def printInorder(root):
  
    if root:
  
        # First recur on left child
        printInorder(root.left)
  
        # then print the data of node
        print(root.val),
  
        # now recur on right child
        printInorder(root.right)
          
  
# Driver code
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
  
print("\nInorder traversal of binary tree is")
printInorder(root)
# Out:
# Inorder traversal of binary tree is
# 4
# 2
# 5
# 1
# 3

# %%
# Python program to for tree traversals
  
# A class that represents an individual node in a
# Binary Tree
class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key
  
# A function to do preorder tree traversal
def printPreorder(root):
  
    if root:
  
        # First print the data of node
        print(root.val),
  
        # Then recur on left child
        printPreorder(root.left)
  
        # Finally recur on right child
        printPreorder(root.right)
  
  
# Driver code
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
print("Preorder traversal of binary tree is")
printPreorder(root)
# Out:
# Preorder traversal of binary tree is
# 1
# 2
# 4
# 5
# 3

# %%
# Python program to for tree traversals
  
# A class that represents an individual node in a
# Binary Tree
class Node:
    def __init__(self, key):
        self.left = None
        self.right = None
        self.val = key
  
          
# A function to do postorder tree traversal
def printPostorder(root):
  
    if root:
  
        # First recur on left child
        printPostorder(root.left)
  
        # the recur on right child
        printPostorder(root.right)
  
        # now print the data of node
        print(root.val),
  
  
# Driver code
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)
  
print("\nPostorder traversal of binary tree is")
printPostorder(root)
# Out:
# Postorder traversal of binary tree is
# 4
# 5
# 2
# 3
# 1

# %% [markdown]
# This calculates the nodes we need to travel to to reach the end, as well as their respective dependent nodes.
# The downside to this is building the tree, as you have to write the left / right branches as you go down, a laborious process.
#
# Instead, there's a simple implementation for this through a package called Networkx that is both fast, and efficient in terms of computing time, as well as having the benefit of being incredibly straightforward to read, visualize, alter, and recalculate as needed.

# %% [markdown]
# We instantiate a directed acyclical graph, and add edges to it.
# Networkx will automatically calculate the nodes and their connections from this.

# %%
import networkx as nx
graph = nx.DiGraph()
graph.add_edges_from([("73", "20"), ("20", "94"), ("20", "97"), ("94", "56"), ("94", "102"), ("97", "102"), ("102","36"), ("102", "37"), ("102", "31"),("56", '102'), ('56', '75'), ('56', '55'),
                     ('75', '31'), ('75', '37'), ('55','31'), ('55', '37'), ('100', '20'),('16', '37'), ('39', '73'), ('39', '100'), ('41', '73'), ('41', '112'), ('62', '55'), ('112', '97'), ('21', '20')])

graph.nodes()
# Out:
# NodeView(('73', '20', '94', '97', '56', '102', '36', '37', '31', '75', '55', '100', '16', '39', '41', '112', '62', '21'))

# %% [markdown]
# A visualization of the nodes of the DAG

# %%
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(12, 8), dpi=80)

val_map = {'73': 1.0,
           '20': 0.5,
           '36': 0.0}

values = [val_map.get(node, 0.25) for node in graph.nodes()]

# Specify the edges you want here

# Need to create a layout when doing
# separate calls to draw nodes and edges
pos = nx.spring_layout(graph)
nx.draw_networkx_nodes(graph, pos, cmap=plt.get_cmap('jet'), 
                       node_color = values, node_size = 250)
nx.draw_networkx_labels(graph, pos)
nx.draw_networkx_edges(graph, pos, edge_color='blacK', arrows=True)
nx.draw_networkx_edges(graph, pos, arrows=False)
plt.show()

# %% [markdown]
# That doesn't really tell us much unfortunately, so let's take a look at the dependencies within the tree, after choosing an end goal

# %% [markdown]
# Inputting our goal task will generate a new node network indicating all task dependencies to complete the final task, as well as the step at which they need to be completed:

# %%
goal_task = nx.dfs_tree(graph.reverse(), source=input('Input End Node')).reverse()
nx.draw(goal_task, with_labels = True)
# Out:
# Input End Node 36

# %%
goal_task.nodes
# Out:
# NodeView(('36', '102', '94', '20', '73', '39', '41', '100', '21', '97', '112', '56'))

# %%
start_task = nx.dfs_tree(graph.reverse(), source=input('Input Start Node')).reverse()
nx.draw(start_task, with_labels = True)
# Out:
# Input Start Node 73

# %% [markdown]
# In this case, we have some prior dependencies that need to be completed prior to starting node 73.
# These dependencies are needed elsewhere in the network as well, so we need to be careful about what we can and can't ignore

# %% [markdown]
# We can first grab the previous connections from the starting task.
# From there, we can use Networkx out_edges to find their connections.
# Using these, we check if each of those connections have two connections - one to the starting point, or maybe one later in the work flow.
# If the connections prior to the starting point only have one connection (i.e. to the starting point itself), we can then safely remove those, as we can assume that they've already been completed in the DAG.

# %%
def task_scheduler(goal, start, graph):
    goal_tasktest = nx.dfs_tree(graph.reverse(), source=goal).reverse()
    start_tasktest = nx.dfs_tree(graph.reverse(), source=start).reverse()
    lst = list(start_tasktest)
    con = []
    for i in lst[1:len(lst)+1]:
        con += list(test.out_edges(i))
    d = {}
    for x, y in con:
        d[x] = d.get(x, 0) + 1
    if 1 in d.values():
        single_node = list(d.keys())[list(d.values()).index(1)]
        goal_tasktest.remove_node(single_node)
        nx.draw(goal_tasktest, with_labels = True)
    else:
        nx.draw(goal_tasktest, with_labels = True)

# %%
task_scheduler('36','73',test)

# %%
list(nx.topological_sort(goal_task))
# Out:
# ['56', '112', '97', '21', '100', '41', '39', '73', '20', '94', '102', '36']

# %%
list(nx.topological_sort(start_task)).index('73')
# Out:
# 2

# %% [markdown]
# Putting this all together we can check if the nodes involved in the start are in the overall network.
# If they're prerequisites for another node we'll leave them, if they're prerequisites for the starting node we can discount them.

# %%
list(graph.out_edges('39'))
list(graph.out_edges('41'))
# Out:
# [('41', '73'), ('41', '112')]

# %%
list(graph.out_edges())
# Out:
# [('73', '20'),
#  ('20', '94'),
#  ('20', '97'),
#  ('94', '56'),
#  ('94', '102'),
#  ('97', '102'),
#  ('56', '102'),
#  ('56', '75'),
#  ('56', '55'),
#  ('102', '36'),
#  ('102', '37'),
#  ('102', '31'),
#  ('75', '31'),
#  ('75', '37'),
#  ('55', '31'),
#  ('55', '37'),
#  ('100', '20'),
#  ('16', '37'),
#  ('39', '73'),
#  ('39', '100'),
#  ('41', '73'),
#  ('41', '112'),
#  ('112', '97'),
#  ('62', '55'),
#  ('21', '20')]

# %%
goal_task.nodes()
# Out:
# NodeView(('36', '102', '94', '20', '73', '39', '41', '100', '21', '97', '112', '56'))

# %%
start_task.nodes()
# Out:
# NodeView(('73', '39', '41'))

# %%
def check(u,v):
    return u in graph.neighbors(v)

check('39','100')
# Out:
# False

# %%
start_tasks = nx.dfs_tree(graph.reverse(), source='73').reverse()

list(start_tasks)
# Out:
# ['73', '39', '41']

# %%
goal = nx.dfs_tree(graph.reverse(), source='36').reverse()

nx.draw(goal, with_labels = True)

# %%
goal_tasks = nx.dfs_tree(graph.reverse(), source='36').reverse()
start_tasks = nx.dfs_tree(graph.reverse(), source='73').reverse()
lst = list(start_tasks)
for i in lst[1:len(lst)+1]:
    if len(list(graph.out_edges(i))) > len(lst):
        print(list(nx.topological_sort(goal_tasks)))
    lif:
        goal_tasks.remove_nodes_from(lst)
        print(list(nx.topological_sort(goal_tasks)))
# Out:
# ['56', '112', '97', '21', '100', '20', '94', '102', '36']
# ['56', '112', '97', '21', '100', '20', '94', '102', '36']

# %%
lst = list(start_tasks)
start_depends = lst[1:len(lst)+1]

# %%
len(start_depends)
# Out:
# 2

# %%
val = 0
for i in start_depends:
    val+= len(list(graph.out_edges(i)))
val
# Out:
# 4

# %%
connecs = []
for i in start_depends:
    connecs += list(graph.out_edges(i))

# %%
connecs
# Out:
# [('39', '73'), ('39', '100'), ('41', '73'), ('41', '112')]

# %%
len(list(graph.out_edges('39')))
# Out:
# 2

# %%
for i in start_depends:
    start_connecs = list(graph.out_edges(i))
if len(start_depends) < len(start_connecs):
    print('po')

# %%
val = 0
for i in start_depends:
    for i in start_depends:
        val+= len(list(graph.out_edges(i)))
    if len(start_depends) < val:
            print('poop')
# Out:
# poop
# poop

# %%
goal_tasks = nx.dfs_tree(graph.reverse(), source='36').reverse()
start_tasks = nx.dfs_tree(graph.reverse(), source='73').reverse()
lst = list(start_tasks)
start_depends = lst[1:len(lst)+1]:
for i in lst[1:len(lst)+1]:
    if len(list(graph.out_edges(i))) < len(lst):
        goal_tasks.remove_nodes_from(lst)
        print(list(nx.topological_sort(goal_tasks)))
# Out:
# ['56', '112', '97', '21', '100', '20', '94', '102', '36']
# ['56', '112', '97', '21', '100', '20', '94', '102', '36']

# %%
print(list(nx.topological_sort(goal_tasks)))
# Out:
# ['56', '112', '97', '21', '100', '41', '39', '73', '20', '94', '102', '36']

# %%
lst = list(start_tasks)

# %%
lst[1:len(lst)+1]
# Out:
# ['39', '41']

# %%
import networkx as nx
test = nx.DiGraph()
test.add_edges_from([('22', '73'), ("73", "20"), ("20", "94"), ("20", "97"), ("94", "56"), ("94", "102"), ("97", "102"), ("102","36"), ("102", "37"), ("102", "31"),("56", '102'), ('56', '75'), ('56', '55'),
                     ('75', '31'), ('75', '37'), ('55','31'), ('55', '37'), ('100', '20'),('16', '37'), ('39', '73'), ('39', '100'), ('41', '73'), ('41', '112'), ('62', '55'), ('112', '97'), ('21', '20')])

goal_tasks = nx.dfs_tree(test.reverse(), source='36').reverse()
start_tasks = nx.dfs_tree(test.reverse(), source='73').reverse()
con = []
for i in lst[1:len(lst)+1]:
    con += list(test.out_edges(i))
con
# Out:
# [('22', '73'), ('39', '73'), ('39', '100'), ('41', '73'), ('41', '112')]

# %%
d = {}
for x, y in con:
        d[x] = d.get(x, 0) + 1
        
d
# Out:
# {'22': 1, '39': 2, '41': 2}

# %%
if 1 in d.values():
    print('ya')
# Out:
# ya

# %%
goal_tasktest = nx.dfs_tree(test.reverse(), source='36').reverse()
start_tasktest = nx.dfs_tree(test.reverse(), source='73').reverse()

# %%
nx.draw(goal_tasktest)

# %%
nodes = ['22', ''

# %%
import networkx as nx
test = nx.DiGraph()
test.add_edges_from([('22', '73'), ("73", "20"), ("20", "94"), ("20", "97"), ("94", "56"), ("94", "102"), ("97", "102"), ("102","36"), ("102", "37"), ("102", "31"),("56", '102'), ('56', '75'), ('56', '55'),
                     ('75', '31'), ('75', '37'), ('55','31'), ('55', '37'), ('100', '20'),('16', '37'), ('39', '73'), ('39', '100'), ('41', '73'), ('41', '112'), ('62', '55'), ('112', '97'), ('21', '20')])

# %%
goal_tasktest = nx.dfs_tree(test.reverse(), source='36').reverse()
start_tasktest = nx.dfs_tree(test.reverse(), source='73').reverse()

# %%
goal_tasktest.remove_nodes_from('22','73')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-283-c7da4340dbb0> in <module>
# ----> 1 goal_tasktest.remove_nodes_from('22','73')
#
# TypeError: remove_nodes_from() takes 2 positional arguments but 3 were given

# %%
nx.draw(goal_tasktest)

# %%
goal_tasktest.remove_node('22')

# %%
nx.draw(goal_tasktest)

# %%
goal_tasktest = nx.dfs_tree(test.reverse(), source='36').reverse()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-267-c3394ae4b816> in <module>
# ----> 1 goal_tasktest = nx.dfs_tree(test.reverse(), source='36').reverse()
#
# AttributeError: 'function' object has no attribute 'reverse'

# %%
nx.draw(goal_tasktest)

# %%
print('100' in graph.nodes())
# Out:
# True

# %%
print(list(mydict.keys())[list(mydict.values()).index(16)])

# %%
import networkx as nx
test = nx.DiGraph()
test.add_edges_from([('22', '73'), ("73", "20"), ("20", "94"), ("20", "97"), ("94", "56"), ("94", "102"), ("97", "102"), ("102","36"), ("102", "37"), ("102", "31"),("56", '102'), ('56', '75'), ('56', '55'),
                     ('75', '31'), ('75', '37'), ('55','31'), ('55', '37'), ('100', '20'),('16', '37'), ('39', '73'), ('39', '100'), ('41', '73'), ('41', '112'), ('62', '55'), ('112', '97'), ('21', '20')])
goal_tasktest = nx.dfs_tree(test.reverse(), source='36').reverse()
start_tasktest = nx.dfs_tree(test.reverse(), source='73').reverse()
lst = list(start_tasktest)
con = []
for i in lst[1:len(lst)+1]:
    con += list(test.out_edges(i))
d = {}
for x, y in con:
    d[x] = d.get(x, 0) + 1

# %%
goal_tasktest.remove_node(list(d.keys())[list(d.values()).index(1)])

# %%
nx.draw(goal_tasktest, with_labels = True)

# %%
def task_scheduler(goal, start, graph):
    goal_tasktest = nx.dfs_tree(graph.reverse(), source=goal).reverse()
    start_tasktest = nx.dfs_tree(graph.reverse(), source=start).reverse()
    lst = list(start_tasktest)
    con = []
    for i in lst[1:len(lst)+1]:
        con += list(test.out_edges(i))
    d = {}
    for x, y in con:
        d[x] = d.get(x, 0) + 1
    if 1 in d.values():
        single_node = list(d.keys())[list(d.values()).index(1)]
        goal_tasktest.remove_node(single_node)
        nx.draw(goal_tasktest, with_labels = True)
    else:
        nx.draw(goal_tasktest, with_labels = True)

# %%
task_scheduler('36', '73', test)

# %%
import networkx as nx
test = nx.DiGraph()
test.add_edges_from([('22', '73'), ("73", "20"), ("20", "94"), ("20", "97"), ("94", "56"), ("94", "102"), ("97", "102"), ("102","36"), ("102", "37"), ("102", "31"),("56", '102'), ('56', '75'), ('56', '55'),
                     ('75', '31'), ('75', '37'), ('55','31'), ('55', '37'), ('100', '20'),('16', '37'), ('39', '73'), ('39', '100'), ('41', '73'), ('41', '112'), ('62', '55'), ('112', '97'), ('21', '20')])

# %%
def task_scheduler(start, end, graph):
    goal_task_test = nx.dfs_tree(graph.reverse(), source=end).reverse()
    start_task = nx.dfs_tree(graph.reverse(), source=start).reverse()
    top_start = list(nx.topological_sort(start_task))
    lst = top_start[:-1]
    goal_task_test.remove_nodes_from(lst)
    return(nx.draw(goal_task, with_labels = True))

# %%
task_scheduler('73', '36', test)

# %%
goal_task_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-1d1a76fec128> in <module>
# ----> 1 goal_task_test
#
# NameError: name 'goal_task_test' is not defined

# %%
lst = []
lst.append(top_start[:-1])

# %%
lst
# Out:
# [['41', '39']]
